# %%
import tushare as ts

# %%
pro = ts.pro_api('c81e523a748f1a7452478bf8c7fe3eeb8fea4820a591898c5462cc5d')

# %%
df = pro.new_share()

# %%
df.head(30)
# Out:
#       ts_code sub_code  name  ipo_date issue_date    amount  market_amount  \
# 0   688765.SH   787765  禾元生物  20251014       None    8945.0            0.0
# 1   601026.SH   780026  道生天合  20250929       None   13188.0            0.0
# 2   920158.BJ   920158  长江能科  20250924       None    3000.0         2400.0
# 3   920080.BJ   920080   奥美森  20250922       None    2000.0         1600.0
# 4   301563.SZ   301563  云汉芯城  20250919       None    1628.0          710.0
# 5   001285.SZ   001285  瑞立科密  20250919       None    4504.0         3282.0
# 6   920015.BJ   920015  锦华新材  20250916   20250925    3757.0         2613.0
# 7   301584.SZ   301584  建发致新  20250916       None    6319.0         2085.0
# 8   301656.SZ   301656  联合动力  20250915       None   28857.0         8113.0
# 9   603418.SH   732418  友升股份  20250912   20250923    4827.0         3199.0
# 10  301668.SZ   301668  昊创瑞通  20250911       None    2790.0         1156.0
# ...
